# %% [markdown]
# # 1. Import Necessary Modules

# %%
#importing necessary modules required for this notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # 2. Load The Dataset

# %%
# loading the dataset "Given_Dataset"

data=pd.read_csv("Given_Dataset.csv")

# %% [markdown]
# # 3. Dataset Features

# %%
# shape of the dataset "Given_Dataset"

data.shape
# Out:
# (583, 11)

# %%
# displaying first five records of the dataset "Given_Dataset"

data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
# displaying last five records of the dataset "Given_Dataset"

data.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2

# %% [markdown]
# # 4. Data Preprocessing

# %%
# Dropping unnecessary columns

print("There is no uncessary columns to drop")
# Out:
# There is no uncessary columns to drop

# %%
# Selecting Target Columns

print("Here \"Dataset\" column is target column")
# Out:
# Here "Dataset" column is target column

# %%
# Selecting independent columns

print("Except \"Dataset\" column all other columns are independent columns")
# Out:
# Except "Dataset" column all other columns are independent columns

# %%
# Displaying the info of dataset "Given_Dataset"

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# # 4.1 Encoding

# %%
# Encoding The categorical column "Gender" into numerical column using label encoding

le=LabelEncoder()
data.Gender=le.fit_transform(data.Gender)

# Displaying the head of the dataset "Given_Dataset" after encoding

data.head()

# After Encoding In "Gender" column
# Female is 0 and Male is 1
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %% [markdown]
# # 4.2 Descriptive Statistics

# %%
# Display the descriptive statistics of the dataset "Given_Dataset"

data.describe()
# Out:
#               Age      Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  583.000000  583.000000       583.000000        583.000000
# mean    44.746141    0.756432         3.298799          1.486106
# std     16.189833    0.429603         6.209522          2.808498
# min      4.000000    0.000000         0.400000          0.100000
# 25%     33.000000    1.000000         0.800000          0.200000
# 50%     45.000000    1.000000         1.000000          0.300000
# 75%     58.000000    1.000000         2.600000          1.300000
# max     90.000000    1.000000        75.000000         19.700000
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count            583.000000                583.000000
# mean             290.576329                 80.713551
# std              242.937989                182.620356
# min               63.000000                 10.000000
# 25%              175.500000                 23.000000
# 50%              208.000000                 35.000000
# 75%              298.000000                 60.500000
# max             2110.000000               2000.000000
#
#        Aspartate_Aminotransferase  Total_Protiens     Albumin  \
# count                  583.000000      583.000000  583.000000
# mean                   109.910806        6.483190    3.141852
# std                    288.918529        1.085451    0.795519
# min                     10.000000        2.700000    0.900000
# 25%                     25.000000        5.800000    2.600000
# 50%                     42.000000        6.600000    3.100000
# 75%                     87.000000        7.200000    3.800000
# max                   4929.000000        9.600000    5.500000
#
#        Albumin_and_Globulin_Ratio     Dataset
# count                  579.000000  583.000000
# mean                     0.947064    1.286449
# std                      0.319592    0.452490
# min                      0.300000    1.000000
# 25%                      0.700000    1.000000
# 50%                      0.930000    1.000000
# 75%                      1.100000    2.000000
# max                      2.800000    2.000000

# %% [markdown]
# # 4.4 Elimination of null values

# %%
# checking whether null value is present or not in each column

data.isnull().any()

# Column "Albumin_and_Globulin_Ratio" has null values
# Out:
# Age                           False
# Gender                        False
# Total_Bilirubin               False
# Direct_Bilirubin              False
# Alkaline_Phosphotase          False
# Alamine_Aminotransferase      False
# Aspartate_Aminotransferase    False
# Total_Protiens                False
# Albumin                       False
# Albumin_and_Globulin_Ratio     True
# Dataset                       False
# dtype: bool

# %%
# total number of null values in each column

data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
# Filling null values with median

data['Albumin_and_Globulin_Ratio'].fillna(data['Albumin_and_Globulin_Ratio'].median(), inplace = True)

# checking for null values after replacement
data.isnull().any()

# THere is no null values
# Out:
# Age                           False
# Gender                        False
# Total_Bilirubin               False
# Direct_Bilirubin              False
# Alkaline_Phosphotase          False
# Alamine_Aminotransferase      False
# Aspartate_Aminotransferase    False
# Total_Protiens                False
# Albumin                       False
# Albumin_and_Globulin_Ratio    False
# Dataset                       False
# dtype: bool

# %% [markdown]
# # 4.5 Unique and Value counts

# %%
# unique values and value counts of "Age" column

data.Age.unique()
# Out:
# array([65, 62, 58, 72, 46, 26, 29, 17, 55, 57, 64, 74, 61, 25, 38, 33, 40,
#        51, 63, 34, 20, 84, 52, 30, 48, 47, 45, 42, 50, 85, 35, 21, 32, 31,
#        54, 37, 66, 60, 19, 75, 68, 70, 49, 14, 13, 18, 39, 27, 36, 24, 28,
#        53, 15, 56, 44, 41,  7, 22,  8,  6,  4, 43, 23, 12, 69, 16, 78, 11,
#        73, 67, 10, 90], dtype=int64)

# %%
data.Age.value_counts()
# Out:
# 60    34
# 45    25
# 50    23
# 42    21
# 38    21
#       ..
# 78     1
# 11     1
# 67     1
# 10     1
# 90     1
# Name: Age, Length: 72, dtype: int64

# %%
# unique values and value counts of "Gender" column

data.Gender.unique()
# Out:
# array([0, 1])

# %%
data.Gender.value_counts()
# Out:
# 1    441
# 0    142
# Name: Gender, dtype: int64

# %%
# unique values and value counts of "Dataset" column

data.Dataset.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
data.Dataset.value_counts()
# Out:
# 1    416
# 2    167
# Name: Dataset, dtype: int64

# %% [markdown]
# # 5. Data Visualizing

# %% [markdown]
# # 5.1 ScatterPlot of Each column

# %%
# "Age" COlumn 

sns.scatterplot(data, x="Age", y="Dataset")
plt.show()

# %%
# "Total_Bilirubin" COlumn 

sns.scatterplot(data, x="Total_Bilirubin", y="Dataset")
plt.show()

# %%
# "Direct_Bilirubin" COlumn 

sns.scatterplot(data, x="Direct_Bilirubin", y="Dataset")
plt.show()

# %%
# "Alkaline_Phosphotase" COlumn 

sns.scatterplot(data, x="Alkaline_Phosphotase", y="Dataset")
plt.show()

# %%
# "Alamine_Aminotransferase" COlumn 

sns.scatterplot(data, x="Alamine_Aminotransferase", y="Dataset")
plt.show()

# %%
# "Aspartate_Aminotransferase" COlumn 

sns.scatterplot(data, x="Aspartate_Aminotransferase", y="Dataset")
plt.show()

# %%
# "Total_Protiens" COlumn 

sns.scatterplot(data, x="Total_Protiens", y="Dataset")
plt.show()

# %%
# "Albumin" COlumn 

sns.scatterplot(data, x="Albumin", y="Dataset")
plt.show()

# %%
# "Albumin_and_Globulin_Ratio" COlumn 

sns.scatterplot(data, x="Albumin_and_Globulin_Ratio", y="Dataset")
plt.show()

# %% [markdown]
# # 5.2 Distribution plot of each column

# %%
# "Age" COlumn

sns.distplot(data.Age)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\3767967868.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Age)

# %%
# "Total_Bilirubin" COlumn

sns.distplot(data.Total_Bilirubin)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\95040016.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Total_Bilirubin)

# %%
# "Direct_Bilirubin" COlumn

sns.distplot(data.Direct_Bilirubin)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\4233420342.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Direct_Bilirubin)

# %%
# "Alkaline_Phosphotase" COlumn

sns.distplot(data.Alkaline_Phosphotase)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\2957062260.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Alkaline_Phosphotase)

# %%
# "Alamine_Aminotransferase" COlumn

sns.distplot(data.Alamine_Aminotransferase)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\414205986.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Alamine_Aminotransferase)

# %%
# "Aspartate_Aminotransferase" COlumn

sns.distplot(data.Aspartate_Aminotransferase)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\829912051.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Aspartate_Aminotransferase)

# %%
# "Total_Protiens" COlumn

sns.distplot(data.Total_Protiens)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\1789377955.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Total_Protiens)

# %%
# "Albumin" COlumn

sns.distplot(data.Albumin)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\1998928814.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Albumin)

# %%
# "Albumin_and_Globulin_Ratio" COlumn

sns.distplot(data.Albumin_and_Globulin_Ratio)
plt.show()
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2320\482387912.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Albumin_and_Globulin_Ratio)

# %% [markdown]
# # 5.4 Correlation and HeatMap

# %%
# Checking the correlation of columns

data.corr()
# Out:
#                                  Age    Gender  Total_Bilirubin  \
# Age                         1.000000  0.056560         0.011763
# Gender                      0.056560  1.000000         0.089291
# Total_Bilirubin             0.011763  0.089291         1.000000
# Direct_Bilirubin            0.007529  0.100436         0.874618
# Alkaline_Phosphotase        0.080425 -0.027496         0.206669
# Alamine_Aminotransferase   -0.086883  0.082332         0.214065
# Aspartate_Aminotransferase -0.019910  0.080336         0.237831
# Total_Protiens             -0.187461 -0.089121        -0.008099
# Albumin                    -0.265924 -0.093799        -0.222250
# Albumin_and_Globulin_Ratio -0.215968 -0.003184        -0.206015
# Dataset                    -0.137351 -0.082416        -0.220208
#
#                             Direct_Bilirubin  Alkaline_Phosphotase  \
# Age                                 0.007529              0.080425
# Gender                              0.100436             -0.027496
# Total_Bilirubin                     0.874618              0.206669
# Direct_Bilirubin                    1.000000              0.234939
# Alkaline_Phosphotase                0.234939              1.000000
# Alamine_Aminotransferase            0.233894              0.125680
# Aspartate_Aminotransferase          0.257544              0.167196
# Total_Protiens                     -0.000139             -0.028514
# Albumin                            -0.228531             -0.165453
# Albumin_and_Globulin_Ratio         -0.199850             -0.233784
# Dataset                            -0.246046             -0.184866
#
#                             Alamine_Aminotransferase  \
# Age                                        -0.086883
# Gender                                      0.082332
# Total_Bilirubin                             0.214065
# Direct_Bilirubin                            0.233894
# Alkaline_Phosphotase                        0.125680
# Alamine_Aminotransferase                    1.000000
# Aspartate_Aminotransferase                  0.791966
# Total_Protiens                             -0.042518
# Albumin                                    -0.029742
# Albumin_and_Globulin_Ratio                 -0.002254
# Dataset                                    -0.163416
#
#                             Aspartate_Aminotransferase  Total_Protiens  \
# Age                                          -0.019910       -0.187461
# Gender                                        0.080336       -0.089121
# Total_Bilirubin                               0.237831       -0.008099
# Direct_Bilirubin                              0.257544       -0.000139
# Alkaline_Phosphotase                          0.167196       -0.028514
# Alamine_Aminotransferase                      0.791966       -0.042518
# Aspartate_Aminotransferase                    1.000000       -0.025645
# Total_Protiens                               -0.025645        1.000000
# Albumin                                      -0.085290        0.784053
# Albumin_and_Globulin_Ratio                   -0.069930        0.233828
# Dataset                                      -0.151934        0.035008
#
#                              Albumin  Albumin_and_Globulin_Ratio   Dataset
# Age                        -0.265924                   -0.215968 -0.137351
# Gender                     -0.093799                   -0.003184 -0.082416
# Total_Bilirubin            -0.222250                   -0.206015 -0.220208
# Direct_Bilirubin           -0.228531                   -0.199850 -0.246046
# Alkaline_Phosphotase       -0.165453                   -0.233784 -0.184866
# Alamine_Aminotransferase   -0.029742                   -0.002254 -0.163416
# Aspartate_Aminotransferase -0.085290                   -0.069930 -0.151934
# Total_Protiens              0.784053                    0.233828  0.035008
# Albumin                     1.000000                    0.686091  0.161388
# Albumin_and_Globulin_Ratio  0.686091                    1.000000  0.162144
# Dataset                     0.161388                    0.162144  1.000000

# %%
# Visual representation of correlation (HeatMap)

plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True)
plt.show()

# There is no much correlation among target column and independent column

# %%
# finding the most correlated independent column with target variable

data.corr().Dataset.sort_values(ascending=False)

#here column "Albumin_and_Globulin_Ratio " is somewhat correlated with the target column
# Out:
# Dataset                       1.000000
# Albumin_and_Globulin_Ratio    0.162144
# Albumin                       0.161388
# Total_Protiens                0.035008
# Gender                       -0.082416
# Age                          -0.137351
# Aspartate_Aminotransferase   -0.151934
# Alamine_Aminotransferase     -0.163416
# Alkaline_Phosphotase         -0.184866
# Total_Bilirubin              -0.220208
# Direct_Bilirubin             -0.246046
# Name: Dataset, dtype: float64

# %%
# multicollinearity

# There is no multicollinearity between two independent columns

# %%
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
#writing the preprocessed data into a csv file
data.to_csv('Preprocessed_Data1.csv')
